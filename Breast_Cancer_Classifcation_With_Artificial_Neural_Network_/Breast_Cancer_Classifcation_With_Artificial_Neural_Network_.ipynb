# %% [markdown]
# Breast Cancer Classifcation With Artificial Neural Network

# %%
# Importing Libraries


import numpy as np
import pandas as pd
import seaborn as sns
import sklearn.datasets
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
# loading the datset from sklearn
df=sklearn.datasets.load_breast_cancer()

# %%
df=pd.DataFrame(df.data,columns=df.feature_names)

# %%
df= pd.read_csv("data.csv")

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  ...  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0    842302         M        17.99  ...          0.4601                  0.11890          NaN
# 1    842517         M        20.57  ...          0.2750                  0.08902          NaN
# 2  84300903         M        19.69  ...          0.3613                  0.08758          NaN
# 3  84348301         M        11.42  ...          0.6638                  0.17300          NaN
# 4  84358402         M        20.29  ...          0.2364                  0.07678          NaN
#
# [5 rows x 33 columns]

# %%
df.shape
# Out:
# (569, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       569 non-null    int64
#  1   diagnosis                569 non-null    object
#  2   radius_mean              569 non-null    float64
#  3   texture_mean             569 non-null    float64
#  4   perimeter_mean           569 non-null    float64
#  5   area_mean                569 non-null    float64
#  6   smoothness_mean          569 non-null    float64
#  7   compactness_mean         569 non-null    float64
#  8   concavity_mean           569 non-null    float64
#  9   concave points_mean      569 non-null    float64
#  10  symmetry_mean            569 non-null    float64
#  11  fractal_dimension_mean   569 non-null    float64
#  12  radius_se                569 non-null    float64
#  13  texture_se               569 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# count  5.690000e+02   569.000000  ...               569.000000          0.0
# mean   3.037183e+07    14.127292  ...                 0.083946          NaN
# std    1.250206e+08     3.524049  ...                 0.018061          NaN
# min    8.670000e+03     6.981000  ...                 0.055040          NaN
# 25%    8.692180e+05    11.700000  ...                 0.071460          NaN
# 50%    9.060240e+05    13.370000  ...                 0.080040          NaN
# 75%    8.813129e+06    15.780000  ...                 0.092080          NaN
# max    9.113205e+08    28.110000  ...                 0.207500          NaN
#
# [8 rows x 32 columns]

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# id                           0.0
# diagnosis                    0.0
# radius_mean                  0.0
# texture_mean                 0.0
# perimeter_mean               0.0
# area_mean                    0.0
# smoothness_mean              0.0
# compactness_mean             0.0
# concavity_mean               0.0
# concave points_mean          0.0
# symmetry_mean                0.0
# fractal_dimension_mean       0.0
# radius_se                    0.0
# texture_se                   0.0
# perimeter_se                 0.0
# area_se                      0.0
# smoothness_se                0.0
# compactness_se               0.0
# concavity_se                 0.0
# concave points_se            0.0
# symmetry_se                  0.0
# fractal_dimension_se         0.0
# radius_worst                 0.0
# texture_worst                0.0
# perimeter_worst              0.0
# area_worst                   0.0
# smoothness_worst             0.0
# compactness_worst            0.0
# ...

# %%
# Target Variable --- M: malignant, B: benign
#  In the Breast Cancer Wisconsin (Diagnostic) Dataset, which is commonly used in machine learning and medical data analysis, the column for diagnosis contains two types of labels:
#M = Malignant (cancerous, harmful)
#B = Benign (non-cancerous, not harmful)

df['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %%
df.replace({'diagnosis': {'B': 0, 'M': 1}}, inplace=True)

# %%
df.groupby(['diagnosis']).mean()
# Out:
#                      id  radius_mean  ...  fractal_dimension_worst  Unnamed: 32
# diagnosis                             ...
# 0          2.654382e+07    12.146524  ...                 0.079442          NaN
# 1          3.681805e+07    17.462830  ...                 0.091530          NaN
#
# [2 rows x 32 columns]

# %%
# Segregate the data

x= df.drop(['diagnosis','id','Unnamed: 32'],axis=1)
y= df['diagnosis']

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.30,random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (398, 30)
# (171, 30)
# (398,)
# (171,)

# %%
ss=StandardScaler()

# %%
x_trains=ss.fit_transform(x_train)
x_tests=ss.transform(x_test)

# %% [markdown]
# Building An Neural Netwrok !

# %%
import tensorflow as tf
from tensorflow import keras

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LeakyReLU,PReLU,ELU,ReLU
from tensorflow.keras.layers import Dropout

# %%
classifier=Sequential()

# %%
#setting the layers for Neural Network!!

# INPUT LAYER
classifier.add(Dense(units=11,activation='relu'))


# HIDDEN LAYER 1
classifier.add(Dense(units=8,activation='relu'))

# HIDDEN LAYER 2
classifier.add(Dense(units=5,activation='relu'))


# OUTPUT LAYER
classifier.add(Dense(1,activation='sigmoid'))

# %%
# Training neural netwrok

classifier.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
#early stopping


early_stopping=tf.keras.callbacks. EarlyStopping(
monitor="val_loss",
min_delta=0.0001,
patience=20,
verbose=1,
mode="auto",
baseline=None,
restore_best_weights=False,
)

# %%
model= classifier.fit(x_trains,y_train,validation_split=0.33, batch_size=10,epochs=1000,callbacks=early_stopping)
# Out:
# Epoch 1/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9964 - loss: 0.0546 - val_accuracy: 0.9697 - val_loss: 0.1285
# Epoch 2/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9996 - loss: 0.0506 - val_accuracy: 0.9697 - val_loss: 0.1276
# Epoch 3/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9982 - loss: 0.0500 - val_accuracy: 0.9697 - val_loss: 0.1273
# Epoch 4/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9980 - loss: 0.0466 - val_accuracy: 0.9697 - val_loss: 0.1269
# Epoch 5/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9990 - loss: 0.0449 - val_accuracy: 0.9697 - val_loss: 0.1266
# Epoch 6/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9980 - loss: 0.0492 - val_accuracy: 0.9697 - val_loss: 0.1259
# Epoch 7/1000
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9961 - loss: 0.0551 - val_accuracy: 0.9697 - val_loss: 0.1257
# Epoch 8/1000
# ...

# %%
# key heads
model.history.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss'])

# %%
#checking accuracy

plt.plot(model.history['accuracy'])
plt.plot(model.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','test'],loc='upper left')
plt.show()

# %%
plt.plot(model.history['loss'])
plt.plot(model.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
# making prediction and evaluate model
y_pred=classifier.predict(x_tests)
y_pred=(y_pred>=0.5)

from sklearn.metrics import confusion_matrix

cm=confusion_matrix(y_test,y_pred)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step

# %%
cm
# Out:
# array([[105,   3],
#        [  2,  61]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9707602339181286

# %% [markdown]
# Building a Predictive Model

# %%
input_data = (19.69, 21.25, 130, 1203, 0.1096, 0.1599, 0.1974, 0.1279, 0.2069, 0.05999,
    0.7456, 0.7869, 4.585, 94.03, 0.00615, 0.04006, 0.03832, 0.02058, 0.0225, 0.004571,
    23.57, 25.53, 152.5, 1709, 0.1444, 0.4245, 0.4504, 0.243, 0.3613, 0.08758)

# change the input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the numpy array as we are predicting for one data point
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

# standardizing the input data
input_data_std = ss.transform(input_data_reshaped)
prediction = classifier.predict(input_data_std)
print(prediction)

#np.argmax return the index of higher value
prediction_label = [np.argmax(prediction)]
print(prediction_label)

if (prediction_label[0] == 0):
  print('The tumor is Malignant')
else:
  print('The tumor is Benign')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# [[1.]]
# [np.int64(0)]
# The tumor is Malignant
